# %%
# 숙제 1.
# 1 ~ 100 까지의 숫자중 3의 배수만 추려서 출력하도록 클래스 및 매서드를 프로그래밍 하시오.

# %%
class Quiz1:
    Quiz1Range = list(range(1,101))

for i in Quiz1Range:
    if i % 3 == 0:
        print("res: {0}".format(i))
# Out:
# res: 3
# res: 6
# res: 9
# res: 12
# res: 15
# res: 18
# res: 21
# res: 24
# res: 27
# res: 30
# res: 33
# res: 36
# res: 39
# res: 42
# res: 45
# res: 48
# res: 51
# res: 54
# res: 57
# res: 60
# res: 63
# res: 66
# res: 69
# res: 72
# res: 75
# res: 78
# res: 81
# res: 84
# res: 87
# res: 90
# res: 93
# res: 96
# res: 99

# %%
# 풀이
for i in range(1,101):
    # i % 3 == 0 보다 비트연산이 빠르다
    if (not(i % 3)):
        print('i = ',i)
# Out:
# i =  3
# i =  6
# i =  9
# i =  12
# i =  15
# i =  18
# i =  21
# i =  24
# i =  27
# i =  30
# i =  33
# i =  36
# i =  39
# i =  42
# i =  45
# i =  48
# i =  51
# i =  54
# i =  57
# i =  60
# i =  63
# i =  66
# i =  69
# i =  72
# i =  75
# i =  78
# i =  81
# i =  84
# i =  87
# i =  90
# i =  93
# i =  96
# i =  99

# %%
# 숙제 2.
# 주사위 게임을 플레이할 수 있도록 클래스 및 매서드를 작성하시오.
# 주사위는 1개만 굴리도록 하며 승패 판정은 누가 더 높은 주사위 눈금을 가지느냐에 따라 갈린다.

# %%
from random import *

class Quiz2:
    comDice = randint(1, 6)
    userDice = randint(1, 6)
    
    def Com(self):
        print(self.comDice)
    def User(self):
        print(self.userDice)
        
    if comDice > userDice:
        print("컴퓨터 승리 == ","computer : ", comDice, "VS", " user : ", userDice)
    elif comDice < userDice:
        print("사용자 승리 == ","computer : ", comDice, "VS", " user : ", userDice)
    elif comDice == userDice:
        print("무승부 == ","computer : ", comDice, "VS", " user : ", userDice)
# Out:
# 컴퓨터 승리 ==  computer :  5 VS  user :  4

# %%
# 풀이
from random import *

class Dice:
    def __init__(self, player):
        self.player = player
        
    def run_dice(self):
        self.dice = randint(1, 6)
        print('{0} - 주사위 눈금은 {1}'.format(self.player, self.dice))
        
    def who_win(self, versus):
        if (self.dice > versus.dice):
            print("{0} 승리".format(self.player))
        elif (self.dice <  versus.dice):
            print("{0} 승리".format(versus.player))
        else:
            print("비김 {0} vs {1}".format(self.dice, versus.dice))
            
    def get_dice(self):
        return self.dice
        
player1 = Dice('플레이어1')
player1.run_dice()

player2 = Dice('플레이어2')
player2.run_dice()

player1.who_win(player2)
# Out:
# 플레이어1 - 주사위 눈금은 6
# 플레이어2 - 주사위 눈금은 3
# 플레이어1 승리

# %%
# 숙제 3.
# 가상의 보드 게임을 만든다.
# 한 바퀴를 도는데 총 주사위 눈금이 40칸이 필요하다.
# 1) 한 바퀴를 돌면 자금으로 100만원이 주어진다.
# 2) 주사위의 특수 능력을 활용할 수 있다.
#   2-1) 숫자 2: 모두의 자금에서 -50만원
#   2-2) 숫자 4: 자신의 자금의 5%가 증발한다.
#   2-3) 숫자 6: 모두의 자금에 30만원을 추가한다.
#   2-4) 모든 플레이어들이 주사위를 돌린 눈금이 짝수일 경우 비밀 상점이 열린다.
#        비밀 상점 물품 : 레드 티켓(지정한 상대의 주사위가 5턴 동안 정지함) - 100만원
#                         옐로우 티켓(지정한 상대의 주사위가 2턴간 정지함) - 50만원
#                         카오스 티켓(아무나 한 명 2턴간 정지함) - 10만원
#                         연속 굴리기(1회, 2회, 3회, 4회) - 20만원
#                         뽑기 티켓(1만원, 2만원, 5만원, 10만원, 20만원, 50만원, 100만원) - 10만원
#   2-5) 플레이어가 필드를 3바퀴 돌면 게임이 종료된다. (주사위 눈금 총 120칸 필요)
#   2-6) 게임이 종료된 이후 가장 많은 자금을 가지고 있는 사람이 경기에 승리하게 된다.
# 게임 팁: 1) 일단 돈을 많이 모은다
#          2) 비밀 상점을 활용하여 대박(뽑기)을 노리거나 상대방을 행동 불능에 빠지게 한다.
#          3) 유리한 상황에서 연속 굴리기를 통해 게임을 빠르게 끝내도록 유도한다.
#          4) 다수가 함께 플레이 할 경우 연속 굴리기를 통해 정치도 가능하다

# %%
from random import *

class boardGame:
    # 주사위 실행 시 자금변화
    minusMoney = 500000
    plusMoney = 300000
    # 플레이어의 자금
    a = 0
    b = 0
    c = 0
    
    # 게임에 사용할 주사위
    gameDice = randint(1, 6)
    # 게임 한바퀴 (40칸)
    round =list(range(1, 41))
    
    # 주사위 조건
    # 2-1
    if gameDice == 2:
        a -= minusMoney
        b -= minusMoney
        c -= minusMoney
    # 2-2
    elif gameDice == 4:
        # 게임 진행자의 자금에서 5% 차감
    # 2-3
    elif gameDice == 6:
        a += plusMoney
        b += plusMoney
        c += plusMoney
    
    
    # 2-4
    for i in gameDice:
        if i % 2 == 0:
            #비밀상점 오픈
# Out:
#   File "<ipython-input-59-b532dfae5ed4>", line 11
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
# 풀이
# 1) Game 클래스
#    1-1) 게임을 종료할 상황인지 판정
#    1-2) 비밀 상점 온/오프 판정
#    1-3) 승리자 판정
#    1-4) 비밀 상점 물품 사용 판정
#    1-5) 광역 스킬 시전 판정
# 2) Player 클래스
# 3) Dice 클래스 (2번 문제 코드 재활용)

# 1) Game 클래스
#    1-1) 게임을 종료할 상황인지 판정
#    1-2) 비밀 상점 온/오프 판정
#    1-3) 승리자 판정
#    1-4) 비밀 상점 물품 사용 판정
#    1-5) 광역 스킬 시전 판정
# 2) Player 클래스
# 3) Dice 클래스 (2번 문제 코드 재활용)

class Game:
    def __init__(self):
        self.secret_store = False
        self.game_end = False
        self.use_chaos_ticket = False
        self.player_arr = []
        self.dice_sum = 0
        
    def open_secret_store(self):
        print(" ** 비밀 상점을 오픈합니다. **")
        # TODO: 숙제
        # 비밀 상점 기능은 실제 루프 돌면서 주사위를 돌리는 플레이어들의 행동을 제한해야함
        # 혹은 연속 돌리기 기능의 경우 다른 플레이어들은 정지 상태로 자신만 돌아야함
        
    def dice_skill(self, player_arr, player_info, cur_dice):
        print("{0} - 주사위 스킬이 발동됩니다.".format(player_info.player))

        # 파이썬에는 switch가 없으므로 if로 구현해야함!
        if cur_dice == 2:
            print("모두의 자금에서 50만원을 차감합니다.")
            
            for i in range(len(player_arr)):
                player_arr[i].withdraw(500000)
                
        elif cur_dice == 4:
            print("{0}의 자금의 5%가 차감됩니다.".format(player_info.player))
            player_info.money -= player_info.money * 0.05
            print("출금: 마이머니 = {0}".format(player_info.money))
            # TODO: 숙제
            
        elif cur_dice == 6:
            print("모두의 자금에서 30만원을 증감됩니다.")
            
            for i in range(len(player_arr)):
                player_arr[i].deposit(300000)
        
        
    def start_game(self):
        self.player = int(input("게임에 참가하는 플레이어는 몇명입니까?"))
        
        for i in range(self.player):
            name = input("플레이어 이름을 적어주세요.")
            self.player_arr.append(Player(name))
            
        while (not(self.game_end)):
            for i in range(self.player):
                self.player_arr[i].run_dice()
                cur_dice = self.player_arr[i].get_dice()
                self.dice_sum += cur_dice
                
                if (not(cur_dice % 2)):
                    self.dice_skill(self.player_arr, self.player_arr[i], cur_dice)
                    
                self.player_arr[i].update_location(cur_dice)
                    
                if (self.player_arr[i].get_lap() == 3):
                    self.game_end = True
                    break
                    
            if (self.game_end):
                break
                
            if (not(self.dice_sum % 2)):
                self.open_secret_store()
                
            self.dice_sum = 0
            
        # 정산을 통해 승자 판정(게임을 먼저 끝내도 4번만 나왔으면 질 수도 있음)
        # TODO: 숙제
        for i in range(len(self.player_arr)):
            print(self.player_arr[i].__dict__)
        
        
class Player(Dice):
    def __init__(self, player):
        super(Player, self).__init__(player)
        # 몇 바퀴 돌았는지
        self.lap = 0
        # 현재 위치
        self.location = 0
        # 소지금
        self.money = 0
        
        print("Player 생성자 호출합니다.")
        
    def update_location(self, dice):
        self.location += dice
        
        if (self.location >= 40):
            self.location -= 40
            self.lap += 1
            
            self.money += 1000000
            
        print("위치값 갱신 lap - {0}, location - {1}".format(self.lap, self.location))
            
    def get_lap(self):
        return self.lap
        
    def withdraw(self, money):
        self.money -= money
        print("출금: 마이머니 = {0}".format(self.money))
        
    def deposit(self, money):
        self.money += money
        print("입금: 마이머니 = {0}".format(self.money))
        
            
        
board_game = Game()
board_game.start_game()

print(board_game.__dict__)
# Out:
# 게임에 참가하는 플레이어는 몇명입니까?2
# 플레이어 이름을 적어주세요.test1
# Player 생성자 호출합니다.
# 플레이어 이름을 적어주세요.test2
# Player 생성자 호출합니다.
# test1 - 주사위 눈금은 1
# 위치값 갱신 lap - 0, location - 1
# test2 - 주사위 눈금은 1
# 위치값 갱신 lap - 0, location - 1
#  ** 비밀 상점을 오픈합니다. **
# test1 - 주사위 눈금은 3
# 위치값 갱신 lap - 0, location - 4
# test2 - 주사위 눈금은 6
# test2 - 주사위 스킬이 발동됩니다.
# 모두의 자금에서 30만원을 증감됩니다.
# 입금: 마이머니 = 300000
# 입금: 마이머니 = 300000
# 위치값 갱신 lap - 0, location - 7
# test1 - 주사위 눈금은 4
# test1 - 주사위 스킬이 발동됩니다.
# test1의 자금의 5%가 차감됩니다.
# 출금: 마이머니 = 285000.0
# 위치값 갱신 lap - 0, location - 8
# test2 - 주사위 눈금은 3
# 위치값 갱신 lap - 0, location - 10
# test1 - 주사위 눈금은 2
# test1 - 주사위 스킬이 발동됩니다.
# 모두의 자금에서 50만원을 차감합니다.
# 출금: 마이머니 = -215000.0
# 출금: 마이머니 = -200000
# 위치값 갱신 lap - 0, location - 10
# test2 - 주사위 눈금은 4
# test2 - 주사위 스킬이 발동됩니다.
# test2의 자금의 5%가 차감됩니다.
# 출금: 마이머니 = -190000.0
# 위치값 갱신 lap - 0, location - 14
#  ** 비밀 상점을 오픈합니다. **
# test1 - 주사위 눈금은 3
# 위치값 갱신 lap - 0, location - 13
# test2 - 주사위 눈금은 6
# test2 - 주사위 스킬이 발동됩니다.
# 모두의 자금에서 30만원을 증감됩니다.
# 입금: 마이머니 = 85000.0
# 입금: 마이머니 = 110000.0
# 위치값 갱신 lap - 0, location - 20
# test1 - 주사위 눈금은 2
# test1 - 주사위 스킬이 발동됩니다.
# 모두의 자금에서 50만원을 차감합니다.
# 출금: 마이머니 = -415000.0
# 출금: 마이머니 = -390000.0
# 위치값 갱신 lap - 0, location - 15
# test2 - 주사위 눈금은 2
# test2 - 주사위 스킬이 발동됩니다.
# 모두의 자금에서 50만원을 차감합니다.
# 출금: 마이머니 = -915000.0
# 출금: 마이머니 = -890000.0
# 위치값 갱신 lap - 0, location - 22
#  ** 비밀 상점을 오픈합니다. **
# test1 - 주사위 눈금은 3
# 위치값 갱신 lap - 0, location - 18
# test2 - 주사위 눈금은 6
# test2 - 주사위 스킬이 발동됩니다.
# 모두의 자금에서 30만원을 증감됩니다.
# 입금: 마이머니 = -615000.0
# 입금: 마이머니 = -590000.0
# 위치값 갱신 lap - 0, location - 28
# test1 - 주사위 눈금은 1
# 위치값 갱신 lap - 0, location - 19
# test2 - 주사위 눈금은 1
# 위치값 갱신 lap - 0, location - 29
#  ** 비밀 상점을 오픈합니다. **
# test1 - 주사위 눈금은 5
# 위치값 갱신 lap - 0, location - 24
# test2 - 주사위 눈금은 1
# 위치값 갱신 lap - 0, location - 30
#  ** 비밀 상점을 오픈합니다. **
# test1 - 주사위 눈금은 3
# 위치값 갱신 lap - 0, location - 27
# test2 - 주사위 눈금은 2
# test2 - 주사위 스킬이 발동됩니다.
# 모두의 자금에서 50만원을 차감합니다.
# 출금: 마이머니 = -1115000.0
# 출금: 마이머니 = -1090000.0
# 위치값 갱신 lap - 0, location - 32
# test1 - 주사위 눈금은 3
# 위치값 갱신 lap - 0, location - 30
# test2 - 주사위 눈금은 1
# 위치값 갱신 lap - 0, location - 33
#  ** 비밀 상점을 오픈합니다. **
# test1 - 주사위 눈금은 6
# test1 - 주사위 스킬이 발동됩니다.
# 모두의 자금에서 30만원을 증감됩니다.
# 입금: 마이머니 = -815000.0
# 입금: 마이머니 = -790000.0
# 위치값 갱신 lap - 0, location - 36
# test2 - 주사위 눈금은 5
# 위치값 갱신 lap - 0, location - 38
# test1 - 주사위 눈금은 2
# test1 - 주사위 스킬이 발동됩니다.
# 모두의 자금에서 50만원을 차감합니다.
# 출금: 마이머니 = -1315000.0
# 출금: 마이머니 = -1290000.0
# 위치값 갱신 lap - 0, location - 38
# test2 - 주사위 눈금은 6
# test2 - 주사위 스킬이 발동됩니다.
# 모두의 자금에서 30만원을 증감됩니다.
# 입금: 마이머니 = -1015000.0
# 입금: 마이머니 = -990000.0
# 위치값 갱신 lap - 1, location - 4
#  ** 비밀 상점을 오픈합니다. **
# test1 - 주사위 눈금은 1
# 위치값 갱신 lap - 0, location - 39
# test2 - 주사위 눈금은 4
# test2 - 주사위 스킬이 발동됩니다.
# test2의 자금의 5%가 차감됩니다.
# 출금: 마이머니 = 9500.0
# 위치값 갱신 lap - 1, location - 8
# test1 - 주사위 눈금은 2
# test1 - 주사위 스킬이 발동됩니다.
# 모두의 자금에서 50만원을 차감합니다.
# 출금: 마이머니 = -1515000.0
# 출금: 마이머니 = -490500.0
# 위치값 갱신 lap - 1, location - 1
# test2 - 주사위 눈금은 2
# test2 - 주사위 스킬이 발동됩니다.
# 모두의 자금에서 50만원을 차감합니다.
# 출금: 마이머니 = -1015000.0
# 출금: 마이머니 = -990500.0
# 위치값 갱신 lap - 1, location - 10
#  ** 비밀 상점을 오픈합니다. **
# test1 - 주사위 눈금은 1
# 위치값 갱신 lap - 1, location - 2
# test2 - 주사위 눈금은 1
# 위치값 갱신 lap - 1, location - 11
#  ** 비밀 상점을 오픈합니다. **
# test1 - 주사위 눈금은 6
# test1 - 주사위 스킬이 발동됩니다.
# 모두의 자금에서 30만원을 증감됩니다.
# 입금: 마이머니 = -715000.0
# 입금: 마이머니 = -690500.0
# 위치값 갱신 lap - 1, location - 8
# test2 - 주사위 눈금은 2
# test2 - 주사위 스킬이 발동됩니다.
# 모두의 자금에서 50만원을 차감합니다.
# 출금: 마이머니 = -1215000.0
# 출금: 마이머니 = -1190500.0
# 위치값 갱신 lap - 1, location - 13
#  ** 비밀 상점을 오픈합니다. **
# test1 - 주사위 눈금은 1
# 위치값 갱신 lap - 1, location - 9
# test2 - 주사위 눈금은 3
# 위치값 갱신 lap - 1, location - 16
#  ** 비밀 상점을 오픈합니다. **
# test1 - 주사위 눈금은 6
# test1 - 주사위 스킬이 발동됩니다.
# 모두의 자금에서 30만원을 증감됩니다.
# 입금: 마이머니 = -915000.0
# 입금: 마이머니 = -890500.0
# 위치값 갱신 lap - 1, location - 15
# test2 - 주사위 눈금은 4
# test2 - 주사위 스킬이 발동됩니다.
# test2의 자금의 5%가 차감됩니다.
# 출금: 마이머니 = -845975.0
# 위치값 갱신 lap - 1, location - 20
#  ** 비밀 상점을 오픈합니다. **
# test1 - 주사위 눈금은 5
# 위치값 갱신 lap - 1, location - 20
# test2 - 주사위 눈금은 3
# 위치값 갱신 lap - 1, location - 23
#  ** 비밀 상점을 오픈합니다. **
# test1 - 주사위 눈금은 4
# test1 - 주사위 스킬이 발동됩니다.
# test1의 자금의 5%가 차감됩니다.
# 출금: 마이머니 = -869250.0
# 위치값 갱신 lap - 1, location - 24
# test2 - 주사위 눈금은 3
# 위치값 갱신 lap - 1, location - 26
# test1 - 주사위 눈금은 4
# test1 - 주사위 스킬이 발동됩니다.
# test1의 자금의 5%가 차감됩니다.
# 출금: 마이머니 = -825787.5
# 위치값 갱신 lap - 1, location - 28
# test2 - 주사위 눈금은 4
# test2 - 주사위 스킬이 발동됩니다.
# test2의 자금의 5%가 차감됩니다.
# 출금: 마이머니 = -803676.25
# 위치값 갱신 lap - 1, location - 30
#  ** 비밀 상점을 오픈합니다. **
# test1 - 주사위 눈금은 2
# test1 - 주사위 스킬이 발동됩니다.
# 모두의 자금에서 50만원을 차감합니다.
# 출금: 마이머니 = -1325787.5
# 출금: 마이머니 = -1303676.25
# 위치값 갱신 lap - 1, location - 30
# test2 - 주사위 눈금은 3
# 위치값 갱신 lap - 1, location - 33
# test1 - 주사위 눈금은 5
# 위치값 갱신 lap - 1, location - 35
# test2 - 주사위 눈금은 2
# test2 - 주사위 스킬이 발동됩니다.
# 모두의 자금에서 50만원을 차감합니다.
# 출금: 마이머니 = -1825787.5
# 출금: 마이머니 = -1803676.25
# 위치값 갱신 lap - 1, location - 35
# test1 - 주사위 눈금은 3
# 위치값 갱신 lap - 1, location - 38
# test2 - 주사위 눈금은 4
# test2 - 주사위 스킬이 발동됩니다.
# test2의 자금의 5%가 차감됩니다.
# 출금: 마이머니 = -1713492.4375
# 위치값 갱신 lap - 1, location - 39
# test1 - 주사위 눈금은 5
# 위치값 갱신 lap - 2, location - 3
# test2 - 주사위 눈금은 4
# test2 - 주사위 스킬이 발동됩니다.
# test2의 자금의 5%가 차감됩니다.
# 출금: 마이머니 = -1627817.815625
# 위치값 갱신 lap - 2, location - 3
# test1 - 주사위 눈금은 1
# 위치값 갱신 lap - 2, location - 4
# test2 - 주사위 눈금은 5
# 위치값 갱신 lap - 2, location - 8
#  ** 비밀 상점을 오픈합니다. **
# test1 - 주사위 눈금은 5
# 위치값 갱신 lap - 2, location - 9
# test2 - 주사위 눈금은 4
# test2 - 주사위 스킬이 발동됩니다.
# test2의 자금의 5%가 차감됩니다.
# 출금: 마이머니 = -596426.9248437501
# 위치값 갱신 lap - 2, location - 12
# test1 - 주사위 눈금은 4
# test1 - 주사위 스킬이 발동됩니다.
# test1의 자금의 5%가 차감됩니다.
# 출금: 마이머니 = -784498.125
# 위치값 갱신 lap - 2, location - 13
# test2 - 주사위 눈금은 4
# test2 - 주사위 스킬이 발동됩니다.
# test2의 자금의 5%가 차감됩니다.
# 출금: 마이머니 = -566605.5786015625
# 위치값 갱신 lap - 2, location - 16
#  ** 비밀 상점을 오픈합니다. **
# test1 - 주사위 눈금은 3
# 위치값 갱신 lap - 2, location - 16
# test2 - 주사위 눈금은 6
# test2 - 주사위 스킬이 발동됩니다.
# 모두의 자금에서 30만원을 증감됩니다.
# 입금: 마이머니 = -484498.125
# 입금: 마이머니 = -266605.57860156253
# 위치값 갱신 lap - 2, location - 22
# test1 - 주사위 눈금은 6
# test1 - 주사위 스킬이 발동됩니다.
# 모두의 자금에서 30만원을 증감됩니다.
# 입금: 마이머니 = -184498.125
# 입금: 마이머니 = 33394.421398437466
# 위치값 갱신 lap - 2, location - 22
# test2 - 주사위 눈금은 1
# 위치값 갱신 lap - 2, location - 23
# test1 - 주사위 눈금은 3
# 위치값 갱신 lap - 2, location - 25
# test2 - 주사위 눈금은 1
# 위치값 갱신 lap - 2, location - 24
#  ** 비밀 상점을 오픈합니다. **
# test1 - 주사위 눈금은 2
# test1 - 주사위 스킬이 발동됩니다.
# 모두의 자금에서 50만원을 차감합니다.
# 출금: 마이머니 = -684498.125
# 출금: 마이머니 = -466605.57860156253
# 위치값 갱신 lap - 2, location - 27
# test2 - 주사위 눈금은 1
# 위치값 갱신 lap - 2, location - 25
# test1 - 주사위 눈금은 5
# 위치값 갱신 lap - 2, location - 32
# test2 - 주사위 눈금은 5
# 위치값 갱신 lap - 2, location - 30
#  ** 비밀 상점을 오픈합니다. **
# test1 - 주사위 눈금은 5
# 위치값 갱신 lap - 2, location - 37
# test2 - 주사위 눈금은 6
# test2 - 주사위 스킬이 발동됩니다.
# 모두의 자금에서 30만원을 증감됩니다.
# 입금: 마이머니 = -384498.125
# 입금: 마이머니 = -166605.57860156253
# 위치값 갱신 lap - 2, location - 36
# test1 - 주사위 눈금은 2
# test1 - 주사위 스킬이 발동됩니다.
# 모두의 자금에서 50만원을 차감합니다.
# 출금: 마이머니 = -884498.125
# 출금: 마이머니 = -666605.5786015625
# 위치값 갱신 lap - 2, location - 39
# test2 - 주사위 눈금은 3
# 위치값 갱신 lap - 2, location - 39
# test1 - 주사위 눈금은 4
# test1 - 주사위 스킬이 발동됩니다.
# test1의 자금의 5%가 차감됩니다.
# 출금: 마이머니 = -840273.21875
# 위치값 갱신 lap - 3, location - 3
# {'player': 'test1', 'lap': 3, 'location': 3, 'money': 159726.78125, 'dice': 4}
# {'player': 'test2', 'lap': 2, 'location': 39, 'money': -666605.5786015625, 'dice': 3}
# {'secret_store': False, 'game_end': True, 'use_chaos_ticket': False, 'player_arr': [<__main__.Player object at 0x000001EAF2599610>, <__main__.Player object at 0x000001EAF2599820>], 'dice_sum': 4, 'player': 2}
